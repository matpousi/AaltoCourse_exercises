# %% [markdown]
# # Task 1.2 Towers of Hanoi
#
# 1. Implement the algorithm in the lecture notes
# 2. Produce the solution for 3, 5 and 7 disks
# 3. [optional] What is the general formula for the number of steps needed to solve the puzzle with $n$ disks?

# %%
def move(frm,to):
  """Print the move from one peg to another."""
  print(f"Move disk from {frm} to {to}")

def move_via(frm,via,to):
  """Move via an auxiliary peg."""
  pass # your code here

def hanoi_solver(n: int,source,auxiliary,target):
  """Print the moves to solve Tower of Hanoi with n disks."""
  pass # your code here

# your code here

# %%
def move(frm,to):
  """Print the move from one peg to another."""
  print(f"Move disk from {frm} to {to}")

def move_via(frm,via,to):
  """Move via an auxiliary peg."""
  move(frm, via)
  move(via, to)

def hanoi_solver(n: int,source,auxiliary,target):
  """Print the moves to solve Tower of Hanoi with n disks."""
  if n == 1:
    move(source, target)
    return 1
  else:
    m1 = hanoi_solver(n - 1, source, target, auxiliary)
    move(source, target),
    m2 = hanoi_solver(n - 1, auxiliary, source, target)
    return m1 + 1 + m2 # return the number of moves

for k in [3,5,7]:
  print(f'Solving Towers of Hanoi with {k} disks:')
  r = hanoi_solver(k,'A','B','C')
  print(f'With {k} disks the solution requires {r} moves\n')
# Out:
# Solving Towers of Hanoi with 3 disks:
# Move disk from A to C
# Move disk from A to B
# Move disk from C to B
# Move disk from A to C
# Move disk from B to A
# Move disk from B to C
# Move disk from A to C
# With 3 disks the solution requires 7 moves
#
# Solving Towers of Hanoi with 5 disks:
# Move disk from A to C
# Move disk from A to B
# Move disk from C to B
# Move disk from A to C
# Move disk from B to A
# Move disk from B to C
# Move disk from A to C
# Move disk from A to B
# Move disk from C to B
# Move disk from C to A
# Move disk from B to A
# Move disk from C to B
# Move disk from A to C
# Move disk from A to B
# Move disk from C to B
# Move disk from A to C
# Move disk from B to A
# Move disk from B to C
# Move disk from A to C
# Move disk from B to A
# Move disk from C to B
# Move disk from C to A
# Move disk from B to A
# Move disk from B to C
# Move disk from A to C
# Move disk from A to B
# Move disk from C to B
# Move disk from A to C
# Move disk from B to A
# Move disk from B to C
# Move disk from A to C
# With 5 disks the solution requires 31 moves
#
# Solving Towers of Hanoi with 7 disks:
# Move disk from A to C
# Move disk from A to B
# Move disk from C to B
# Move disk from A to C
# Move disk from B to A
# Move disk from B to C
# Move disk from A to C
# Move disk from A to B
# Move disk from C to B
# Move disk from C to A
# Move disk from B to A
# Move disk from C to B
# Move disk from A to C
# Move disk from A to B
# Move disk from C to B
# Move disk from A to C
# Move disk from B to A
# Move disk from B to C
# Move disk from A to C
# Move disk from B to A
# Move disk from C to B
# Move disk from C to A
# Move disk from B to A
# Move disk from B to C
# Move disk from A to C
# Move disk from A to B
# Move disk from C to B
# Move disk from A to C
# Move disk from B to A
# Move disk from B to C
# Move disk from A to C
# Move disk from A to B
# Move disk from C to B
# Move disk from C to A
# Move disk from B to A
# Move disk from C to B
# Move disk from A to C
# Move disk from A to B
# Move disk from C to B
# Move disk from C to A
# Move disk from B to A
# Move disk from B to C
# Move disk from A to C
# Move disk from B to A
# Move disk from C to B
# Move disk from C to A
# Move disk from B to A
# Move disk from C to B
# Move disk from A to C
# Move disk from A to B
# Move disk from C to B
# Move disk from A to C
# Move disk from B to A
# Move disk from B to C
# Move disk from A to C
# Move disk from A to B
# Move disk from C to B
# Move disk from C to A
# Move disk from B to A
# Move disk from C to B
# Move disk from A to C
# Move disk from A to B
# Move disk from C to B
# Move disk from A to C
# Move disk from B to A
# Move disk from B to C
# Move disk from A to C
# Move disk from B to A
# Move disk from C to B
# Move disk from C to A
# Move disk from B to A
# Move disk from B to C
# Move disk from A to C
# Move disk from A to B
# Move disk from C to B
# Move disk from A to C
# Move disk from B to A
# Move disk from B to C
# Move disk from A to C
# Move disk from B to A
# Move disk from C to B
# Move disk from C to A
# Move disk from B to A
# Move disk from C to B
# Move disk from A to C
# Move disk from A to B
# Move disk from C to B
# Move disk from C to A
# Move disk from B to A
# Move disk from B to C
# Move disk from A to C
# Move disk from B to A
# Move disk from C to B
# Move disk from C to A
# Move disk from B to A
# Move disk from B to C
# Move disk from A to C
# Move disk from A to B
# Move disk from C to B
# Move disk from A to C
# Move disk from B to A
# Move disk from B to C
# Move disk from A to C
# Move disk from A to B
# Move disk from C to B
# Move disk from C to A
# Move disk from B to A
# Move disk from C to B
# Move disk from A to C
# Move disk from A to B
# Move disk from C to B
# Move disk from A to C
# Move disk from B to A
# Move disk from B to C
# Move disk from A to C
# Move disk from B to A
# Move disk from C to B
# Move disk from C to A
# Move disk from B to A
# Move disk from B to C
# Move disk from A to C
# Move disk from A to B
# Move disk from C to B
# Move disk from A to C
# Move disk from B to A
# Move disk from B to C
# Move disk from A to C
# With 7 disks the solution requires 127 moves
